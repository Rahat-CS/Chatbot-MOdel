# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("./big.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b861461bf68e> in <module>()
# ----> 1 words = read_corpus("./big.txt")
#       2 print(f"There are {len(words)} total words in the corpus")
#
# <ipython-input-3-11fcc5f7e281> in read_corpus(filename)
#       1 def read_corpus(filename):
# ----> 2   with open(filename, "r") as file:
#       3     lines = file.readlines()
#       4     words = []
#       5     for line in lines:
#
# FileNotFoundError: [Errno 2] No such file or directory: './big.txt'

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 23904 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 503

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["love"])
# Out:
# 0.0023657193389756298

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete(" trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'tramsh', 'trasho', 'nrash', 'tqrash', 'trqash', 'arash', 'trasv', 'tfash', 'tsrash', 'trach', 'rrash', 'thash', 'ctrash', 'traih', 'tbrash', 'btrash', 'trakh', 'prash', 'trysh', 'trask', 'utrash', 'trabh', 'trasgh', 'tqash', 'tresh', 'ktrash', 'tralsh', 'trazsh', 'tgrash', 'traxsh', 'trasih', 'trashh', 'trlash', 'trmsh', 'hrash', 'traash', 'tratsh', 'tprash', 'trashm', 'trzash', 'trashi', 'trasmh', 'trast', 'rash', 'trvsh', 'transh', 'zrash', 'trazh', 'trashf', 'trasf', 'trashk', 'trsah', 'irash', 'trasp', 'trasvh', 'ptrash', 'tramh', 'trasdh', 'tyash', 'traksh', 'ytrash', 'trpsh', 'grash', 'vtrash', 'trasc', 'tmrash', 'tvash', 'trasu', 'tkrash', 'qtrash', 'trauh', 'trtsh', 'trsh', 'trjash', 'trayh', 'trvash', 'trasqh', 'toash', 'rtash', 'torash', 'trwash', 'trashy', 'ntrash', 'tsash', 'trath', 'trkash', 'tnrash', 'trush', 'traqh', 'trasbh', 'trasjh', 'trajsh', 'trgsh', 'trasch', 'tcrash', 'trrsh', 'erash', 'tras', 'tvrash', 'tmash', 'txrash', 'trasj', 'trashw', 'etrash', 'wtrash', 'traush', 'trashr', 'srash', 'mtrash', 'trashe', 'traeh', 'ttrash', 'tgash', 'trasy', 'triash', 'twrash', 'orash', 'tuash', 'trashs', 'krash', 'trasg', 'trhsh', 'trasuh', 'troash', 'traqsh', 'thrash', 'tiash', 'trashu', 'itrash', 'trafsh', 'trasxh', 'trashl', 'tarash', 'trarh', 'trashj', 'trasyh', 'traslh', 'trasha', 'trasq', 'tzrash', 'trassh', 'trapsh', 'gtrash', 'otrash', 'wrash', 'trashz', 'yrash', 'tragh', 'trashp', 'trashx', 'tlash', 'tyrash', 'traah', 'atrash', 'trabsh', 'trsash', 'txash', 'trfash', 'terash', 'trcsh', 'trawsh', 'traseh', 'traskh', 'trashn', 'trasw', 'trasb', 'rtrash', 'tnash', 'trass', 'ztrash', 'tash', 'twash', 'trbash', 'tjrash', 'traish', 'trosh', 'trashd', 'qrash', 'trbsh', 'trksh', 'trasz', 'trcash', 'trpash', 'traxh', 'treash', 'trase', 'traoh', 'trahsh', 'trasht', 'trxash', 'trwsh', 'trasd', 'dtrash', 'trawh', 'drash', 'ltrash', 'trasm', 'trasph', 'lrash', 'trlsh', 'ftrash', 'trasrh', 'xtrash', 'tradh', 'tfrash', 'tlrash', 'traosh', 'travsh', 'trafh', 'traesh', 'trish', 'trasx', 'traswh', 'trasfh', 'taash', 'trasl', 'trjsh', 'teash', 'trasnh', 'trah', 'xrash', 'tbash', 'tzash', 'trrash', 'trhash', 'trzsh', 'trtash', 'tradsh', 'mrash', 'trasah', 'trasoh', 'vrash', 'trashq', 'trashv', 'trasr', 'tracsh', 'trarsh', 'trasa', 'trgash', 'tcash', 'trdash', 'tralh', 'trqsh', 'trasn', 'tdrash', 'trmash', 'trash', 'trajh', 'trnash', 'truash', 'ttash', 'jrash', 'trahs', 'frash', 'trdsh', 'traszh', 'tdash', 'traso', 'traph', 'brash', 'trasi', 'tarsh', 'tryash', 'jtrash', 'trasth', 'trahh', 'tkash', 'turash', 'trashg', 'tranh', 'strash', 'tirash', 'tragsh', 'traysh', 'htrash', 'trashc', 'trnsh', 'tjash', 'crash', 'trssh', 'urash', 'trxsh', 'trfsh', 'travh', 'trashb', 'tpash'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'tlaksh', 'tjrashj', 'trarph', 'trbaslh', 'trxish', 'tzasch', 'trxahs', 'atrashu', 'otresh', 'dradh', 'traaf', 'mraswh', 'ttraosh', 'brasho', 'trso', 'zracsh', 'tjashm', 'tqwsh', 'tsaosh', 'trashqj', 'tiaskh', 'strahs', 'ngrash', 'mtdrash', 'rtrasdh', 'thaash', 'vtrwsh', 'crxsh', 'trbaph', 'trcsfh', 'vrasw', 'frpsh', 'trayf', 'trmzash', 'etruash', 'tdasnh', 'gtraesh', 'rrazh', 'ctrahs', 'tiassh', 'tdfrash', 'traszqh', 'trcaqh', 'xrdsh', 'tzraash', 'travsoh', 'traedh', 'trgjsh', 'trqsb', 'trhasnh', 'trhaszh', 'orasb', 'tnasyh', 'tgrase', 'trawso', 'htrasb', 'trazsl', 'tvdash', 'xrasha', 'trwavsh', 'trasrb', 'trlhh', 'torarsh', 'jtrasht', 'ywash', 'thlrash', 'tratss', 'krasha', 'jrawsh', 'trsrh', 'trxaeh', 'praxh', 'tnrcash', 'vrsah', 'trasjt', 'rrtash', 'btrasth', 'stkash', 'trasphd', 'txrwsh', 'azash', 'qrakh', 'twaskh', 'trrakh', 'rraoh', 'trascdh', 'trqasx', 'trgalsh', 'trausrh', 'ttjsh', 'gtralh', 'atrash', 'irsh', 'feash', 'tcrfash', 'torasd', 'gtrawh', 'mtradh', 'tyksh', 'trasljh', 'vroash', 'trashvd', 'trjoash', 'jtrahh', 'gtvash', 'trasjhi', 'rresh', 'tqasa', 'tvath', 'tkaoh', 'tffrash', 'trahah', 'trgxsh', 'gtraso', 'trvosh', 'traswc', 'tnrasqh', 'traqshv', 'trasquh', 'traap', 'etrgash', 'urashm', 'twamsh', 'uthash', 'rtrzsh', 'tttsh', 'tratshd', 'trashko', 'trlasd', 'erhash', 'trasag', 'krazsh', 'tuakh', 'praih', 'tnasho', 'trcanh', 'tkashl', 'trqazh', 'tcasr', 'mraosh', 'traxsv', 'kxrash', 'thrasvh', 'trwxh', 'trqsho', 'trpshd', 'troshe', 'trsass', 'btrath', 'mttrash', 'tjlash', 'tramskh', 'tfsah', 'utrwash', 'ctrksh', 'tprashh', 'eraso', 'trashgi', 'trankh', 'tqaph', 'trarqsh', 'itramh', 'trasbhx', 'trnashr', 'tyrashl', 'ltrasz', 'tgrasdh', 'irasha', 'vtrxash', 'mraso', 'trawhg', 'tvashf', 'tkrish', 'trwshd', 'tzesh', 'tcrahs', 'vtnash', 'ttrasvh', 'xrasoh', 'tqraseh', 'wrasxh', 'smash', 'trarshl', 'trtaswh', 'tqrafh', 'tdashd', 'trisc', 'tdraslh', 'amash', 'vtrlash', 'trqyash', 'yrazh', 'tnish', 'strsh', 'drssh', 'tqrjsh', 'trasju', 'tdaph', 'ytyrash', 'uhrash', 'dtrashn', 'ntroash', 'tkashh', 'okrash', 'ktraswh', 'trbosh', 'trtsm', 'raskh', 'trazsi', 'tdaosh', 'otrasp', 'turgash', 'trfamh', 'ftransh', 'ptrashe', 'tradsch', 'tmrdsh', 'cgtrash', 'trhshv', 'trfsash', 'jtravsh', 'aeash', 'tfashw', 'trasux', 'wrwash', 'trxaush', 'traeq', 'trasbb', 'trasha', 'tsjrash', 'trannh', 'trzaph', 'tbashe', 'trayo', 'tvruash', 'tuasy', 'tbrdash', 'tradhe', 'htrashh', 'truamsh', 'trasuhq', 'ctraqsh', 'rthash', 'trgsgh', 'trahskh', 'tqrashf', 'orasth', 'dtrasnh', 'ppash', 'triasl', 'atrasdh', 'trwamsh', 'grlash', 'otrashn', 'tbrrash', 'trcasm', 'tryasg', 'travhj', 'trvlsh', 'qaash', 'tryxash', 'rrjash', 'derash', 'trfgsh', 'ytrase', 'ztvrash', 'trnkh', 'tryapsh', 'gtrbsh', 'trllh', 'twosh', 'ktash', 'traxsf', 'trapsjh', 'hraksh', 'strasfh', 'arashe', 'tiagh', 'tyasn', 'yrast', 'trnhh', 'yrvash', 'hraph', 'ltrashv', 'tuasbh', 'trazeh', 'txaxsh', 'trtasht', 'trafsgh', 'iwrash', 'tgakh', 'trmasvh', 'ztrasyh', 'xtrafsh', 'trtahs', 'jtrashz', 'trsmah', 'tarskh', 'tradxsh', 'utrashh', 'yttrash', 'trpsw', 'trazhc', 'txrashx', 'twaih', 'triasbh', 'trlasb', 'trashjn', 'draskh', 'strfsh', 'trzsj', 'trasayh', 'trasbhl', 'ntirash', 'rtrashu', 'trpaseh', 'tkdsh', 'vtrtash', 'tiasb', 'trxadh', 'tzrasa', 'stresh', 'tjrsash', 'tvashy', 'traflh', 'trafshh', 'treasp', 'trasazh', 'naash', 'tprgsh', 'trashhz', 'tzrashw', 'traehy', 'taragh', 'gtpash', 'trhdsh', 'trashdg', 'trapgh', 'tnrmsh', 'trgbh', 'strasrh', 'trashrh', 'gtrnsh', 'trjasah', 'tnrashv', 'zrashv', 'kmrash', 'trajsh', 'otgash', 'trkshl', 'thasl', 'trapsch', 'txasth', 'graxh', 'atrgash', 'tvraush', 'trjsih', 'trerash', 'ewtrash', 'trqkh', 'mtriash', 'mtrysh', 'trasti', 'tfasyh', 'tnryash', 'trau', 'tsaqsh', 'xtragsh', 'ntrashx', 'trkaosh', 'otrpash', 'ptrashn', 'twasn', 'ctrmsh', 'traoph', 'trcsf', 'trasthn', 'tradyh', 'trasdhw', 'rrbsh', 'ntrvash', 'cttash', 'thwash', 'trvasho', 'tbravsh', 'urasht', 'tcradh', 'grajh', 'trvcsh', 'trsaxh', 'ftras', 'hrasl', 'utranh', 'tvashn', 'ttashl',  ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('family', 8.606527836200562e-06), ('facile', 1.0758159795250702e-06), ('famine', 1.2909791754300844e-05)]
# famine is suggested for famile

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("./big.txt")

# %%
checker.check("mi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9032ba65380a> in <module>()
# ----> 1 checker.check("mi")
#
# NameError: name 'checker' is not defined
